# %% [markdown]
# # <a href="https://miptstats.github.io/courses/ad_mipt.html">Phystech@DataScience</a>
# ## Домашнее задание 7
#
# **Правила, <font color="red">прочитайте внимательно</font>:**
#
# * Выполненную работу нужно отправить телеграм-боту `@miptstats_pds_bot`. Для начала работы с ботом каждый раз отправляйте `/start`. **Работы, присланные иным способом, не принимаются.**
# * Дедлайн см. в боте. После дедлайна работы не принимаются кроме случаев наличия уважительной причины.
# * Прислать нужно ноутбук в формате `ipynb`.
# * Выполнять задание необходимо полностью самостоятельно. **При обнаружении списывания все участники списывания будут сдавать устный зачет.**
# * Решения, размещенные на каких-либо интернет-ресурсах, не принимаются. Кроме того, публикация решения в открытом доступе может быть приравнена к предоставлении возможности списать.
# * Для выполнения задания используйте этот ноутбук в качестве основы, ничего не удаляя из него. Можно добавлять необходимое количество ячеек.
# * Комментарии к решению пишите в markdown-ячейках.
# * Выполнение задания (ход решения, выводы и пр.) должно быть осуществлено на русском языке.
# * Если код будет не понятен проверяющему, оценка может быть снижена.
# * Никакой код из данного задания при проверке запускаться не будет. *Если код студента не выполнен, недописан и т.д., то он не оценивается.*
# * **Код из рассказанных на занятиях ноутбуков можно использовать без ограничений.**
#
# **Правила оформления теоретических задач:**
#
# * Решения необходимо прислать одним из следующих способов:
#   * фотографией в правильной ориентации, где все четко видно, а почерк разборчив,
#     * отправив ее как файл боту вместе с ноутбуком *или*
#     * вставив ее в ноутбук посредством `Edit -> Insert Image` (<font color="red">фото, вставленные ссылкой, не принимаются</font>);
#   * в виде $LaTeX$ в markdown-ячейках.
# * Решения не проверяются, если какое-то требование не выполнено. Особенно внимательно все проверьте в случае выбора второго пункта (вставки фото в ноутбук). <font color="red"><b>Неправильно вставленные фотографии могут не передаться при отправке.</b></font> Для проверки попробуйте переместить `ipynb` в другую папку и открыть его там.
# * В решениях поясняйте, чем вы пользуетесь, хотя бы кратко. Например, если пользуетесь независимостью, то достаточно подписи вида "*X и Y незав.*"
# * Решение, в котором есть только ответ, и отсутствуют вычисления, оценивается в 0 баллов.
#
# **Баллы за задание:**
#
# <b><font color="blue">Легкая часть</font></b> (достаточно на "хор"):
# * Задача 1 &mdash; 15 баллов
# * Задача 2 &mdash; 15 баллов
# * Задача 3 &mdash; 20 баллов
# * Задача 4 &mdash; 30 баллов
#
# <b><font color="orange">Сложная часть</font></b> (необходимо на "отл"):
#
# * Задача 5 &mdash; 30 баллов
# * Задача 6 &mdash; 20 баллов
#
#
#
#
# -----

# %%
# Bot check

# HW_ID: phds_hw7
# Бот проверит этот ID и предупредит, если случайно сдать что-то не то.

# Status: final
# Перед отправкой в финальном решении удали "not" в строчке выше.
# Так бот проверит, что ты отправляешь финальную версию, а не промежуточную.
# Никакие значения в этой ячейке не влияют на факт сдачи работы.

# %%
import numpy as np
import scipy.stats as sps
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set_theme(font_scale=1.3, palette='Set2')
import math

red = '#FF3300'
blue = '#0099CC'
green = '#00CC66'

# %matplotlib inline

# %% [markdown]
# # Теоретическая часть
#
# ### <b><font color="blue">Легкая часть</font></b>
#
# ## Задача 1
#
# В условиях задач 2, 3 и 6 из предыдущего домашнего задания постройте асимптотические доверительные интервалы, которые можно использовать на практике (в формулах не должно быть $\theta$).

# %% [markdown]
# СМ. ПРИКРЕПЛЕННЫЙ ФАЙЛ

# %% [markdown]
# # Практическая часть
#
# ### <b><font color="blue">Легкая часть</font></b>
#
# ## Задача 2
#
# **1.** Загрузите с помощью `pandas` из файла `airquality.csv` данные о качестве воздуха в Нью-Йорке с мая по сентябрь 1973 года по дням. Данные содержат измерения нескольких величин, описания которых можно прочитать [по ссылке](https://www.rdocumentation.org/packages/datasets/versions/3.5.1/topics/airquality).

# %%
data = pd.read_csv("airquality.csv")
data.head()
# Out:
#    Ozone  Solar.R  Wind  Temp  Month  Day
# 0   41.0    190.0   7.4    67      5    1
# 1   36.0    118.0   8.0    72      5    2
# 2   12.0    149.0  12.6    74      5    3
# 3   18.0    313.0  11.5    62      5    4
# 4    NaN      NaN  14.3    56      5    5

# %% [markdown]
# Выведите описательные статистики (метод `describe`) для всех признаков, для которых это имеет смысл.  Округлите до второго знака после запятой.

# %%
round(data.describe(), 2)
# Out:
#         Ozone  Solar.R    Wind    Temp   Month     Day
# count  116.00   146.00  153.00  153.00  153.00  153.00
# mean    42.13   185.93    9.96   77.88    6.99   15.80
# std     32.99    90.06    3.52    9.47    1.42    8.86
# min      1.00     7.00    1.70   56.00    5.00    1.00
# 25%     18.00   115.75    7.40   72.00    6.00    8.00
# 50%     31.50   205.00    9.70   79.00    7.00   16.00
# 75%     63.25   258.75   11.50   85.00    8.00   23.00
# max    168.00   334.00   20.70   97.00    9.00   31.00

# %% [markdown]
# Что можно сказать о наличии в данных выбросов, сравнивая выборочную медиану и выборочное среднее?

# %% [markdown]
# **Ответ:** медиана и выборочное среднее не сильно отличаются друг от друга (на 0-10%). Это свидетельствует о том, что скорее всего выбросов не слишком много или они вовсе отсутствуют

# %% [markdown]
# **2.** Теперь для каждого параметра постройте график ящиков с усами (`boxplot`), в котором ось `x` соответствует номеру месяца, а ось `y` — значениям параметра (т.е. свой ящик для каждого месяца). Используйте функцию `seaborn.boxplot`.

# %%
params = ["Ozone", "Solar.R", "Wind", "Temp"]

fig, axes = plt.subplots(1, 4, figsize=(30, 8))
for i, param in enumerate(params):
    with sns.plotting_context("notebook"), sns.axes_style("darkgrid"):
        sns.boxplot(x=data['Month'], ax=axes[i], y=data[param])

# %% [markdown]
# Опишите структуру `boxplot`. Какие выводы можно сделать в данном случае?

# %% [markdown]
# **Ответ:** нижняя часть уса показывает минимальное значение, которое можно получить, исключая выбросы. Нижняя часть ящика соответствует первому квантилю, т.е. 25% значений находится под ним. Линия внутри ящика соответствует второму квантилю, т.е. медиане. Верхняя часть ящика - 3-ий квантиль, ниже него 75% значений, верхняя часть уса показывает максимальное значение, которое мы получаем, то что выше - выбросы.
#
#
# Выводы в нашем случае: данные достаточно симметричные и есть небольшое колличество выбросов "Temp" в 6 и 7 месяце, в "Wind" в 6, в "Ozone" во всех кроме 7 и в "Solar.R" в 7.

# %% [markdown]
# **3.** Для параметра с наибольшим числом наблюдений, признанных выбросами, посчитайте и сравните:
# - выборочное среднее;
# - выборочную медиану;

# %%
round(data["Ozone"].describe(), 2)
# Out:
# count    116.00
# mean      42.13
# std       32.99
# min        1.00
# 25%       18.00
# 50%       31.50
# 75%       63.25
# max      168.00
# Name: Ozone, dtype: float64

# %% [markdown]
# Какими свойствами статистик вызваны наблюдаемые различия?

# %% [markdown]
# **Ответ:**
# - выборочное среднее = 42.13
# - выборочная медиана = 31.5
#
# Высокие значения параметра "Ozone", такие как 168, могут сильно влиять на среднее значение, но не так сильно на медиану. Выбросы могут “потянуть” среднее вверх, в то время как медиана остается более устойчивой к выбросам. Также это единственный параметр, в котором мы можем наблюдать асимметрию в данных.

# %% [markdown]
# При подсчете этих статистик обычно предполагается, что наблюдения независимы. Выполнено ли это свойство в данном случае?

# %%
months = [5, 6, 7, 8, 9]

fig, axes = plt.subplots(1, 5, figsize=(50, 15))

for i, month in enumerate(months):
    sns.heatmap(data=data[data['Month'] == months[i]].drop("Month", axis=1).corr(), ax=axes[i], annot=True)
    axes[i].set_title(f'Корреляционная матрица в {months[i]} месяце', fontsize=15)

# %% [markdown]
# **Ответ:** независимость не выполнена так как есть сильно коррелированные величины в каждом месяце, например в 6 месяце "Ozone" и "Solar.R" коррелирую со всеми параметрами.

# %% [markdown]
# А оно часто бывает выполнено? Как это можно проверить? Что бывает, когда оно нарушается? Какие есть количественные меры зависимости между признаками? Ответы на эти вопросы вы узнаете далее, но задуматься и порассуждать полезно уже сейчас.

# %% [markdown]
# **Ответ:** Кажется, что независимость не выполнена никогда в нашем мире, потому что нельзя утверждать, что мы знаем все связи между элементами. Для оценки у нас есть ковариация и полезный инструмент из нее - это коэффициент кореляции

# %% [markdown]
# Сделайте выводы о полезности робастных статистик, методах визуального анализа и о наличии независимых одинаково распределённых случайных величин в реальном мире.

# %% [markdown]
# **Вывод:** Хорошо когда данные наглядные, тогда мы можем посмотреть на работу с разных сторон, а не только будем вычислять коэффициенты. О полной независимости двух величин в реальности говорить скорее всего нельзя

# %% [markdown]
# ## Задача 3

# %% [markdown]
# Постройте плотность стандартного **нормального распределения** и стандартного **распределения Коши**. Видим, что распределение Коши обладает более тяжелыми хвостами, нежели нормальное.

# %%
grid = np.linspace(-10, 10, 1000)

plt.figure(figsize=(10, 10))
plt.plot(grid, sps.cauchy.pdf(grid), color=green, label='Cauchy(1)')
plt.plot(grid, sps.norm.pdf(grid), color=blue, label='$\mathcal{N}(0, 1)$')
plt.title('Плотности распределений')
plt.legend()

# %% [markdown]
# Сгенерируйте $10^5$ выборок размера 30 из стандартного **нормального распределения**.

# %%
sample_count = 10**5
sample_size = 30

samples = sps.norm.rvs(size=(sample_count, sample_size))

# %% [markdown]
# По каждой выборке из 30 элементов посчитайте выборочные средние. Далее по ним постройте гистограмму и плотность стандартного нормального распределения. Какой вывод вы можете сделать из полученного графика?

# %%
elems = [samples[i, :].mean() for i in range(sample_count)]
sns.histplot(elems, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
grid = np.linspace(-5, 5, 1000)
plt.plot(grid, sps.norm.pdf(grid), color=blue, label='$\mathcal{N}(0, 1)$')

# %% [markdown]
# **Вывод:** При большом количестве выборок можно использовать асимптотический доверительный интервал.

# %% [markdown]
# Сгенерируем $10^5$ выборок размера 30 из стандартного **распределения Коши**.

# %%
sample_count = 10**5
sample_size = 30

samples = sps.cauchy.rvs(size=(sample_count, sample_size))

# %% [markdown]
# Построим аналогичный график.

# %%
elems = [samples[i, :].mean() for i in range(sample_count)]
plt.xlim([-5, 5])
sns.histplot(elems, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
grid = np.linspace(-5, 5, 1000)
plt.plot(grid, sps.cauchy.pdf(grid), color=blue, label='Cauchy(1)')

# %% [markdown]
# Сравните графики для нормального распределения и для Коши, опишите ваше сравнение в выводе по задаче.

# %% [markdown]
# **Вывод:** У распределения Коши нет ни математического ожидания, ни дисперсии, поэтому для него нет АДИ. Для него мы получили что-то непонятное в отличии от стандартного нормального распределения

# %% [markdown]
# ## Задание 4

# %% [markdown]
# **Профиль Физика**
#
# Скачайте <a target="_blank" href="https://www.kaggle.com/datasets/fedesoriano/cern-electron-collision-data">данные</a> столкновениях частиц и оставьте следующие признаки:
# * `E1`, `E2` &mdash; полная энергия электронов (ГэВ);
# * `M` &mdash; инвариантная масса двух электронов (ГэВ).
#
# Датасет большой, поэтому для ускорения расчетов можно взять подвыборку размера ~ 1000
#
# **Профиль Биология**
#
# Скачайте <a target="_blank" href="https://www.kaggle.com/datasets/ruslankl/mice-protein-expression">данные</a> экспрессии белков у белых мышей и оставьте следующие белки для анализа:
# * `ITSN1_N`
# * `DYRK1A_N`
# * `ELK_N`
#
#
#
#
# **1.** Постройте для каждого из них гистограммы. Что можно сказать о характере распределения?

# %%
df = pd.read_csv("dielectron.csv")

features = ["E1", "E2", "M"]
df = df[features]

df = df.head(1000)

round(df.describe(), 2)
# Out:
#             E1       E2        M
# count  1000.00  1000.00  1000.00
# mean     33.49    39.89    27.22
# std      37.08    41.68    23.44
# min       0.96     0.83     2.00
# 25%       8.02     9.92    11.49
# 50%      19.52    21.58    19.24
# 75%      47.45    61.69    33.74
# max     285.89   262.04   109.90

# %% [markdown]
# **Ответ:** данные сильно разбросаны, имеют выбросы

# %% [markdown]
# **2.** Пусть есть выборка $X_1, ..., X_n$. Опишите процедуру бутстрепа построения доверительного интервала для величины $\theta = \mathsf{E} X_1$. Рассмотрите три типа  бутстрепных доверительных интервалов.
# Выпишите соответствующие формулы.

# %% [markdown]
# **Описание**: СМ. ПРИЛОЖЕННЫЙ ФАЙЛ

# %% [markdown]
# **3.** Реализуйте функцию вычисления выборки оценок $\theta^*_1, \ldots \theta^*_B$ для оценки $\widehat \theta$ методом бутстрепа. Функция должна принимать на вход выборку и количество бутстрепных выборок $B$.
#
# Для ускорения расчетов можете использовать broadcasting (не является обязательным требованием). Учите, что в таком случае внутри функции у вас могут получиться очень большие матрицы, из-за которых может кончиться оперативная память.

# %%
def bootstrap(sample, B=1000): 
    '''
    Считает бутстрепные оценки для исходной выборки

    :param sample: исходная выборка
    :param B: количество бутстрепных 
    :return bootstrap_estimations: оценки по бутстрепным выборкам
    '''   
    
    B = len(sample)
    bootstrap_estimations = np.random.choice(sample, size=(B, B), replace=True)
    bootstrap_estimations = np.sort(np.mean(bootstrap_estimations, axis=1))

    return bootstrap_estimations

# %% [markdown]
# **4.** Реализуйте три типа бутстрепных доверительных интервалы в виде функций, принимающих на вход выборку оценок, полученных с помощью бутстрепа. Реализовывать вычисление бутстрепных интервалов для подвыборок размера от 1 до n не нужно, только для всей выборки.

# %%
def bootstrap_normal_confidence_interval(theta, bootstrap_estimations, alpha=0.95):
    '''
    Считает левую и правую границу нормального бутстрепного интервала

    :param theta: оценка параметра
    :param bootstrap_estimations: массив бутстрепных оценок
    :return left: левая граница бутстрепного интервала
    :return right: правая граница бутстрепного интервала
    '''   


    v = np.var(bootstrap_estimations)
    
    z = sps.norm.ppf((1 + alpha) / 2)
    
    left = theta - z * v**0.5
    right = theta + z * v**0.5

    return round(left, 2), round(right, 2)


    
def bootstrap_central_confidence_interval(theta, bootstrap_estimations, alpha=0.95):
    '''
    Считает левую и правую границу центрального бутстрепного интервала

    :param theta: оценка параметра
    :param bootstrap_estimations: массив бутстрепных оценок
    :return left: левая граница бутстрепного интервала
    :return right: правая граница бутстрепного интервала
    '''   

    B = len(bootstrap_estimations)

    
    left = 2*theta -  bootstrap_estimations[math.ceil(B*(1+alpha)*0.5)-1]
    right = 2*theta - bootstrap_estimations[int(B*(1-alpha)*0.5)-1]
    
    
    return round(left, 2), round(right, 2)


    
def bootstrap_quantile_confidence_interval(theta, bootstrap_estimations, alpha=0.95):
    '''
    Считает левую и правую границу квантильного бутстрепного интервала

    :param theta: оценка параметра
    :param bootstrap_estimations: массив бутстрепных оценок
    :return left: левая граница бутстрепного интервала
    :return right: правая граница бутстрепного интервала
    '''   
    
    B = len(bootstrap_estimations)
    
    left =  bootstrap_estimations[int(B*(1-alpha)/2)-1]
    right =  bootstrap_estimations[math.ceil(B*(1+alpha)/2)-1]

    return round(left, 2), round(right, 2)

# %% [markdown]
# **5.** Для каждого признака постройте бутстрепные доверительные интервалы для $\theta = \mathsf{E} X_1$ и сравните их.

# %%
dat = pd.DataFrame(index = ['normal', 'central', 'quantile', 'theta', 'interval_length'], columns=df.columns)

for col in df.columns:
    # Получим бутстрепные оценки
    bootstrap_estimations = bootstrap(df[col])

    # Вычислим оценку параметра
    theta = round(np.mean(df[col]), 2)

    # Построим доверительные интервалы
    dat.loc['normal', col] = bootstrap_normal_confidence_interval(theta, bootstrap_estimations)
    dat.loc['central', col] = bootstrap_central_confidence_interval(theta, bootstrap_estimations)
    dat.loc['quantile', col] = bootstrap_quantile_confidence_interval(theta, bootstrap_estimations)
    
    dat.loc['theta', col] = theta
    dat.loc['interval_length', col] = [round(dat.loc['normal', col][1] - dat.loc['normal', col][0], 2),
                                       round(dat.loc['central', col][1] - dat.loc['central', col][0], 2),
                                       round(dat.loc['quantile', col][1] - dat.loc['quantile', col][0], 2)]

dat
# Out:
#                                  E1                  E2                   M
# normal               (31.25, 35.73)      (37.35, 42.43)      (25.78, 28.66)
# central              (31.07, 35.61)      (37.35, 42.47)      (25.64, 28.62)
# quantile             (31.37, 35.91)      (37.31, 42.43)       (25.82, 28.8)
# theta                         33.49               39.89               27.22
# interval_length  [4.48, 4.54, 4.54]  [5.08, 5.12, 5.12]  [2.88, 2.98, 2.98]

# %% [markdown]
# **Вывод:** бутстрепные интервалы для конкретного признака не сильно отличаются друг от друга.

# %% [markdown]
# Визуализируйте бутстрепные интервалы для каждого признака. Для этого сгенерируйте выборку $X_1, ... X_{N}, N = 100$ и постройте график доверительных интервалов уровня доверия $0.95$, вычисленных для всех подвыборок размера $n$ вида $X_1, ... X_n$, $1 \le n \le 100$, используя написанную ниже функцию

# %%
def draw_confidence_interval(
    left,
    right,
    estimation=None,
    sample=None, 
    ylim=(None, None), 
    estim_label = '',
    sample_label='',
    color=("green", "red", "blue"),
    interval_label=None,
    title=''
):
    '''
    Рисует доверительный интервал и оценку в зависимости от размера выборки.
    
    :param left: левые границы интервалов (в зависимости от n)
    :param right: правые границы интервалов (в зависимости от n)
    :param estimation: оценки (в зависимости от n)
    :param sample: выборка
    :param ylim: ограничение вертикальной оси
    :param estim_label: подпись к оценке
    :param sample_label: подпись к выборке
    :param color: цвет, которым будет отображен доверительный интервал
    '''
    lin = ["normal confidence interval", "central confidence interval", "quantile confidence interval"]

    
    plt.figure(figsize=(10, 6))
    for i in range(len(left)):
        plt.fill_between(range(1, len(sample) + 1), left[i], right[i], color=color[i], alpha=0.08, label=lin[i])
        plt.plot(range(1, len(sample) + 1), estimation[i], color=color[i], label=f"sample min for {lin[i]}")
    for i in range(0, len(sample)):
        plt.scatter((i+1) * np.ones(len(sample[i])), sample[i], color='blue', alpha=0.005)
    plt.xlabel('Sample Size (n)')
    plt.ylabel('Value')
    plt.title(f'Confidence Intervals for {title}')
    plt.ylim(ylim)
    plt.legend()
    plt.show()

# %% [markdown]
# **Решение:**

# %%
n_values = np.arange(1, 101)

sample_size = 100


np.random.seed(207)


col = ["E1", "E2", "M"]
lin = ["normal", "central", "quantile"]



for i,c in enumerate(col):
    left_intervals = [[], [], []]
    right_intervals = [[], [], []]
    estimations = [[], [], []]
    samples = []

    for n in range (2, sample_size):
        data = df.head(n)
        samples.append(data[c].to_numpy())
  
        
        bootstrap_estimations = bootstrap(data[col[0]])
        theta = round(np.mean(data[col[0]]), 2)
        estimations[0].append(theta)
        interval = bootstrap_normal_confidence_interval(theta, bootstrap_estimations)
        left_intervals[0].append(interval[0])
        right_intervals[0].append(interval[1])
        
        bootstrap_estimations = bootstrap(data[col[1]])
        theta = round(np.mean(data[col[1]]), 2)
        estimations[1].append(theta)
        interval = bootstrap_central_confidence_interval(theta, bootstrap_estimations)
        left_intervals[1].append(interval[0])
        right_intervals[1].append(interval[1])   
        
        bootstrap_estimations = bootstrap(data[col[2]])
        theta = round(np.mean(data[col[2]]), 2)
        estimations[2].append(theta)
        interval = bootstrap_quantile_confidence_interval(theta, bootstrap_estimations)
        left_intervals[2].append(interval[0])
        right_intervals[2].append(interval[1])   
    
    
    
    draw_confidence_interval(
        left_intervals,
        right_intervals,
        estimation=estimations,
        sample=samples,
        ylim=None,
        estim_label='Sample Mean',
        sample_label='Sample',
        color=('green', "blue", "red"),
        interval_label=f'Feature {i+1} Confidence Interval',
        title=c
    )

# %% [markdown]
# **Вывод:**
#
# Нормальный бутстрепный доверительный интервал: оценивает с использованием нормального распределения.
#
# Центральный бутстрепный доверительный интервал: оценивает с использованием распределения средних значений. Из графиков видно, как этот доверительный интервал стремится к среднему значению по всей выборке.
#
# Квантильный бутстрепный доверительный интервал: оценивает с использованием квантилей распределения бутстреп-выборок

# %% [markdown]
# ### <b><font color="orange">Сложная часть</font></b>
#
# ## Задача 5
#
#
# Предлагается изучить некоторые свойства распределения Коши с параметром сдвига $\theta$, обладающего плотностью распределения $p_{\theta}(x) = \frac{1}{\pi \left(1 + \left(x- \theta\right)^2\right)}$.
#
# На высоте 1 метр от точки $\theta$ находится источник $\gamma$-излучения,
# причем направления траекторий $\gamma$-квантов случайны, т.е. равномерно распределены по полуокружности. Тогда $X_i, i=1,...,n$ — зарегистрированные координаты точек пересечения $\gamma$-квантов с поверхностью детекторной плоскости — образуют выборку из распределения Коши со сдвигом $\theta$.

# %% [markdown]
# **1.** На отрезке $[-7, 7]$ постройте плотность стандартного нормального распределения и стандартного распределения Коши. Не забудьте добавить легенду. Сделайте выводы о сходствах и различиях распределений

# %% [markdown]
# **Решение:**

# %%
x = np.linspace(-7, 7, 1000)

normal = (1 / np.sqrt(2 * np.pi)) * np.exp(-x**2 / 2)
cauchy = 1 / (np.pi * (1 + x**2))

plt.figure(figsize=(10, 10))
plt.plot(x, normal, label='Стандартное нормальное распределение')
plt.plot(x, cauchy, label='Стандартное распределение Коши', color='red')
plt.xlabel('x')
plt.ylabel('Плотность вероятности')
plt.title('Сравнение стандартного нормального и распределения Коши')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Вывод:** стандартное распределение более локализовано в отличии от распределения Коши. Из этого следует, что величины, распределенные по коши с большей вероятностью принимают значения отклоненные от среднего.

# %% [markdown]
# **2.** Чему равна асимптотическая дисперсия $\sigma_{\alpha}^2$ усеченного среднего $\overline{X}_{\alpha}$, где $0 < \alpha < 1/2$, для распределения Коши? Помочь в ее вычислении может теорема, упомянутая на лекциях. Посчитайте асимптотическую дисперсию аналитически. Постройте график зависимости асимптотической дисперсии $\sigma_{\alpha}^2$ усеченного среднего $\overline{X}_{\alpha}$, где $0 < \alpha < 1/2$, от $\alpha$.
#
# Настройте видимую область графика по оси *y* так, чтобы четко была отображена информативная часть графика. Отметьте на графике минимум функции.

# %% [markdown]
# СМ. ПРИКРЕПЛЕННЫЙ ФАЙЛ.

# %% [markdown]
# **Решение:**

# %%
def z(q):
    return sps.cauchy.ppf(q)


def asymptotic_variance(alpha):
    return (2 / (1 - 2 * alpha)**2) * ((1/np.pi)*z(1-alpha) - (1/np.pi)*np.arctan(z(1 - alpha)) + alpha*(z(1-alpha))**2)


alpha_values = np.linspace(0.01, 0.99, 100000)

# Вычисляем асимптотическую дисперсию для каждого alpha
variance_values = asymptotic_variance(alpha_values)

# Находим минимальное значение дисперсии и соответствующее alpha
min_variance = np.min(variance_values)
optimal_alpha = alpha_values[np.argmin(variance_values)]


plt.figure(figsize=(10, 10))
plt.plot(alpha_values, variance_values, label='Асимптотическая дисперсия')
plt.scatter(optimal_alpha, min_variance, color='red', marker='o', label='Минимум дисперсии')
plt.xlabel('Alpha (Уровень усечения)')
plt.ylabel('Асимптотическая дисперсия')
plt.title('Асимптотическая дисперсия усеченного среднего для распределения Коши')
plt.legend()
plt.grid(True)
plt.ylim(0, 10)  
plt.show()


print(f"Минимальная асимптотическая дисперсия: {min_variance:.6f} (при alpha = {optimal_alpha:.6f})")
# Out:
# Минимальная асимптотическая дисперсия: 2.277645 (при alpha = 0.380316)

# %% [markdown]
# При каком значении $\alpha$ асимптотическая дисперсия $\sigma^2_{\alpha}$ минимальна и чему она равна? Ответ можно найти численно.

# %% [markdown]
# **Ответ:** Минимальная асимптотическая дисперсия: 2.277645 при alpha = 0.380316. Получена численно из графика.

# %% [markdown]
# **3.** Сгенерируйте выборку $X = \left(X_1, \dots, X_{1000} \right)$ из стандартного распределения Коши. Для всех $n \leqslant 1000$ по первым $n$ элементам выборки $X_1, \dots, X_n$ вычислите значения следующих оценок:
# - $\overline{X}$  —  выборочное среднее;
# - $\overline{X}_{\alpha}$ —  усеченное среднее, где $\alpha$ &mdash; значение, на котором достигается минимум $\sigma^2_{\alpha}$;
# - $\widehat{\mu}$ —  выборочная медиана;
#
# На графиках изобразите зависимость значений **всех оценок** от $n$ для одной реализации выборки, а на другом графики траекторий по нескольким реализациям.
#
# Постройте также график, на котором изобразите значения MSE для каждой оценки от размера выборки $n$.
#
# *Указание:* $MSE_{\widehat{\theta}}(\theta) = (\widehat{\theta} - \theta)^2$. В качестве $\theta$ возьмите истинное значение для стандартного распределения Коши. Для подсчета усеченного среднего можно использовать функцию `scipy.stats.trim_mean`.
#
# Сравните асимптотические дисперсии оценок. Сделайте вывод.
#
# **Решение:**

# %%
np.random.seed(207)

sample_size = 1000
sample = sps.cauchy.rvs(size=sample_size)

sample_means = np.cumsum(sample) / np.arange(1, sample_size + 1)
sample_trimmed_means = np.array([sps.trim_mean(sample[:n], proportiontocut=0.1) for n in range(1, sample_size + 1)])
sample_medians = np.array([np.median(sample[:n]) for n in range(1, sample_size + 1)])

true_value = 0

mse_means = (sample_means - true_value) ** 2
mse_trimmed_means = (sample_trimmed_means - true_value) ** 2
mse_medians = (sample_medians - true_value) ** 2

plt.figure(figsize=(10, 6))
plt.plot(range(1, sample_size + 1), sample_means, label="Sample Mean")
plt.plot(range(1, sample_size + 1), sample_trimmed_means, label="Trimmed Mean")
plt.plot(range(1, sample_size + 1), sample_medians, label="Sample Median")
plt.axhline(y=true_value, color='gray', linestyle='--', label="True Value")
plt.xlabel("размер выборки (n)")
plt.ylabel("значение оценки")
plt.title("Траектории оценок с одной реализацией")
plt.legend()
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(range(1, sample_size + 1), mse_means, label="Sample Mean")
plt.plot(range(1, sample_size + 1), mse_trimmed_means, label="Trimmed Mean")
plt.plot(range(1, sample_size + 1), mse_medians, label="Sample Median")
plt.xlabel("размер выборки (n)")
plt.ylabel("MSE")
plt.title("MSE для оценок")
plt.legend()
plt.show()

# %% [markdown]
# **Вывод:**
#
# Выборочное среднее и усеченное среднее имеют практически одинаковую асимптотическую дисперсию. В целом, выборочное среднее и усеченное среднее являются хорошими оценками для стандартного распределения Коши, особенно при больших размерах выборки.

# %% [markdown]
# ## Задача 6
# Асимпотические доверительные интервалы ничего не могут гарантировать на малых размерах выборки.
# В этой задаче вам предстоит иллюстрировать этот факт, посчитав реальный уровень доверия для интервалов.
#
# **Реальный уровень доверия (оценка доли покрытия интервалом)**  - доля случаев попадания истинного значения параметра в доверительный интервал.
#
# *Пример:* вы проводите 100 экспериментов (создаете 100 выборок), для каждой выборки рассчитываете АДИ для параметра $\theta$. Истинный параметр попадает в 93 интервала из 100, значит реальный уровень доверия в этом случае будет 0.93.
#
# **Важно:** при такой оценке реального уровня доверия вы используете метод Монте-Карло. Погрешность этого метода составляет $\sim \frac{1}{\sqrt{n}}$, где $n$ - количество выборок, по которым осуществляется оценка.
#
# *Вопрос:* какое $n$ нужно брать, если вы хотите оценить реальный уровень доверия с точностью до 2 знаков ($\delta = 0.01$)?
#
# **Ответ:** n = 10000

# %% [markdown]
# Сгенерируйте набор выборок из нормального распределения $\mathcal{N}(\theta, 1)$ при $\theta=0$

# %%
theta = 0

sample_size = 300
sample_count = 10000

X = np.random.normal(loc=theta, scale=1, size=(sample_count, sample_size))
X.shape
# Out:
# (10000, 300)

# %% [markdown]
# Рассмотрим $\hat{\theta} = \overline{X}$.
#
# Напоминание из теории:
# $$\hat{\theta} - \frac{z_{\frac{1+\alpha}{2}}\hat{\sigma}}{\sqrt{n}} < \theta < \hat{\theta} + \frac{z_{\frac{1+\alpha}{2}}\hat{\sigma}}{\sqrt{n}}$$

# %% [markdown]
# Посчитайте $z$ (используйте функцию `.ppf`)

# %%
theta = 0

sample_size = 300

alpha = 0.95

z = sps.norm.ppf((1 + alpha)/ 2)


error = z / np.sqrt(sample_size)

lower_bound_treory = theta - error
upper_bound_treory = theta + error

print(f"Доверительный интервал: ({lower_bound_treory:.4f}, {upper_bound_treory:.4f})")
# Out:
# Доверительный интервал: (-0.1132, 0.1132)

# %% [markdown]
# Постройте график зависимости реального уровня доверия от размера выборки.

# %%
theta = 0
sample_size = 1000
sample_count = 10000

X = np.random.normal(loc=theta, scale=1, size=(sample_count, sample_size))


sample_sizes = np.arange(10, sample_size+1, 10)
coverage_probabilities = []

for size in sample_sizes:
    sample_means = np.mean(X[:, :size], axis=1)
    sample_std = np.std(sample_means, ddof=1)
    lower_bound = sample_means - z * sample_std / np.sqrt(size)
    upper_bound = sample_means + z * sample_std / np.sqrt(size)
    actual_coverage = np.mean((lower_bound < theta) & (theta < upper_bound))
    coverage_probabilities.append(actual_coverage)

plt.figure(figsize=(10, 6))
plt.plot(sample_sizes, coverage_probabilities, marker='o', linestyle='', color='b', label='real')



plt.xlabel('размер выборки')
plt.ylabel('уровень доверия')
plt.title('Фактическая вероятность покрытия от размера выборки')

x = np.linspace(10, sample_size+1, 1000)
plt.plot(x, sps.norm.ppf((1 + alpha)/ 2) / np.sqrt(x), label="treory")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Сделайте выводы.

# %% [markdown]
# **Вывод:** практический уровень доверия имеет ту же форму, что и теоретический. Однако при малых значениях выборки они расходятся сильнее, т.е. в действительности доля случаев попадания истинного значения параметра в доверительный интервал меньше.
